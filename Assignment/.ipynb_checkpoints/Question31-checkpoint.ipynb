# %%
import sqlite3
import pandas as pd
import numpy as np
# import relevant library

# %%
housing_database_connect = sqlite3.connect("housing.db")
housing_df = pd.read_sql("SELECT * FROM houses",housing_database_connect)
housing_df.head()  #make connection with database
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   2217  909279080           50        RL           NaN     11275   Pave
# 1    837  907126050           20        RL          65.0      9757   Pave
# 2   2397  528144030           60        RL          86.0     11065   Pave
# 3   1963  535452060           20        RL          70.0      7000   Pave
# 4    306  911202100           50   C (all)          66.0      8712   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC Fence Misc Feature  \
# 0  None       IR1          HLS  ...         0    None  None         None
# 1  None       Reg          Low  ...         0    None  None         None
# 2  None       IR1          Lvl  ...         0    None  None         None
# 3  None       Reg          Lvl  ...         0    None  MnWw         None
# 4  Pave       Reg          HLS  ...         0    None  None         None
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# 0        0       3    2007       WD           Normal     220000
# 1        0      10    2009       WD           Normal     143000
# 2        0      10    2006       New         Partial     281000
# 3        0       4    2007       WD           Family     135000
# 4        0       1    2010       WD          Abnorml     102776
#
# [5 rows x 81 columns]

# %%
normal_df = housing_df[housing_df['Sale Condition']=='Normal']
# select Sales data under normal condition
column_names = ['Year Built','Gr Liv Area','Total Bsmt SF','SalePrice']
# select target column
subset = normal_df[column_names]
subset_df = pd.DataFrame(subset)
subset_df_clean = subset_df.dropna()
# clean out irrelevent data display
house_age = 2010 - subset_df_clean['Year Built']
# calculate house age
subset_df_clean['Age'] = house_age

# %%
price_correlation = subset_df_clean.corr()['SalePrice'].abs().sort_values()
price_correlation
# figure out correlation of the variables
# Out:
# Age              0.520716
# Year Built       0.520716
# Total Bsmt SF    0.635165
# Gr Liv Area      0.740554
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
y = subset_df_clean['SalePrice']
x = subset_df_clean['Total Bsmt SF']
fig = plt.figure()
plt.scatter(x,y,alpha=0.2)
plt.show()
# shows the relationship between SalesPrice and total basement size on plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
y = subset_df_clean['SalePrice']
x = subset_df_clean['Gr Liv Area']
fig = plt.figure()
plt.scatter(x,y,alpha=0.2)
plt.show()
# shows the relationship between SalesPrice and living area on plot

# %% [markdown]
# # Question 2

# %%
# Question 2
import statsmodels.api as sm
y = subset_df_clean['SalePrice']
x = subset_df_clean[['Gr Liv Area','Total Bsmt SF']]
model1 = sm.OLS(y, x)
results1 = model1.fit()
print(results1.summary())
#
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.955
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                 2.035e+04
# Date:                Mon, 15 Apr 2019   Prob (F-statistic):               0.00
# Time:                        15:02:58   Log-Likelihood:                -23183.
# No. Observations:                1928   AIC:                         4.637e+04
# Df Residuals:                    1926   BIC:                         4.638e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Gr Liv Area      76.0048      1.592     47.737      0.000      72.882      79.127
# Total Bsmt SF    63.9637      2.257     28.338      0.000      59.537      68.390
# ==============================================================================
# Omnibus:                      385.456   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2347.097
# Skew:                           0.795   Prob(JB):                         0.00
# Kurtosis:                       8.166   Cond. No.                         5.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# model with intercept

import statsmodels.api as sm

x_with_intercept = sm.add_constant(x, prepend=True)

x_with_intercept.head()

model = sm.OLS(y, x_with_intercept)

results2 = model.fit()

print(results2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.687
# Model:                            OLS   Adj. R-squared:                  0.687
# Method:                 Least Squares   F-statistic:                     2117.
# Date:                Mon, 15 Apr 2019   Prob (F-statistic):               0.00
# Time:                        15:02:58   Log-Likelihood:                -23156.
# No. Observations:                1928   AIC:                         4.632e+04
# Df Residuals:                    1925   BIC:                         4.634e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const         -2.348e+04   3198.698     -7.342      0.000   -2.98e+04   -1.72e+04
# Gr Liv Area      85.6549      2.048     41.821      0.000      81.638      89.672
# Total Bsmt SF    71.1174      2.431     29.259      0.000      66.350      75.884
# ==============================================================================
# Omnibus:                      205.378   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1303.705
# Skew:                           0.271   Prob(JB):                    8.02e-284
# Kurtosis:                       6.992   Cond. No.                     6.61e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.61e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
# Question 2 C  for model 1  RMS

from sklearn.metrics import mean_squared_error
from math import sqrt


y_predicted1 = results1.predict(x) #predict y


rms = sqrt(mean_squared_error(y, y_predicted1))
print(round(rms,3))
# Out:
# 40353.738

# %%
# C for model 2 RMS
y_predicted2 = results2.predict(x_with_intercept) #predict y

rms = sqrt(mean_squared_error(y, y_predicted2))
print(round(rms,3))
# Out:
# 39800.385

# %%
# C for model 1 R squared
from sklearn.metrics import r2_score
r2 = r2_score(y, y_predicted1)
print(round(r2,3))
# C for model 1 R squared
r2 = r2_score(y, y_predicted2)
print(round(r2,3))
# Out:
# 0.679
# 0.687

# %% [markdown]
# # Question 2 D

# %%
fitted_values = y_predicted2
residual1 = y_predicted2 - y
plt.scatter(fitted_values,residual1, alpha = 0.1)
plt.xlabel("Fitted Values")
plt.ylabel("Residuals")
plt.title("Fitted values against residuals")
plt.show()

# %%
fitted_values = y_predicted2
residual1 = y_predicted2 - y
residual2 = residual1**2        
# square redsiduals
plt.scatter(fitted_values,residual2, alpha = 0.1)
plt.xlabel("Fitted Values")
plt.ylabel("Squared residuals")
plt.title("Fitted values against square residuals")
plt.show()

# %% [markdown]
# # Question 3

# %%
price_correlation = housing_df.corr()['SalePrice'].abs().sort_values()
price_correlation
# Out:
# BsmtFin SF 2       0.009460
# Misc Val           0.013345
# Yr Sold            0.027967
# Bsmt Half Bath     0.032120
# Order              0.032304
# 3Ssn Porch         0.035768
# Mo Sold            0.036491
# Low Qual Fin SF    0.036709
# Pool Area          0.082848
# MS SubClass        0.090156
# Overall Cond       0.102492
# Screen Porch       0.105246
# Kitchen AbvGr      0.116482
# Enclosed Porch     0.134733
# Bedroom AbvGr      0.145614
# Bsmt Unf SF        0.175869
# PID                0.244288
# 2nd Flr SF         0.275200
# Lot Area           0.276240
# Bsmt Full Bath     0.277212
# Half Bath          0.286110
# Wood Deck SF       0.326140
# Open Porch SF      0.329714
# Lot Frontage       0.358778
# BsmtFin SF 1       0.434615
# Fireplaces         0.472859
# TotRms AbvGrd      0.494807
# Mas Vnr Area       0.500203
# Garage Yr Blt      0.528347
# Year Remod/Add     0.530925
# Full Bath          0.539633
# Year Built         0.551663
# 1st Flr SF         0.621018
# Total Bsmt SF      0.624879
# Garage Area        0.636071
# Garage Cars        0.646797
# Gr Liv Area        0.708936
# SalePrice          1.000000
# Name: SalePrice, dtype: float64

# %%
normal_df = housing_df[housing_df['Sale Condition']=='Normal']
# select Sales data under normal condition
column_names = ['Year Built','Gr Liv Area','Total Bsmt SF','SalePrice','Central Air']
# select target column
subset = normal_df[column_names]
subset_df = pd.DataFrame(subset)
subset_df_clean1 = subset_df.dropna()
# clean out irrelevent data display
house_age = 2010 - subset_df_clean['Year Built']
# calculate house age
subset_df_clean1['Age'] = house_age
subset_df_clean1.head()
# Out:
#    Year Built  Gr Liv Area  Total Bsmt SF  SalePrice Central Air  Age
# 0        1932         1991          854.0     220000           Y   78
# 1        1994          990          990.0     143000           Y   16
# 5        1995         1609          754.0     182000           Y   15
# 7        1971          981          981.0     143250           Y   39
# 8        1959         1466         1466.0     149900           Y   51

# %%
price_correlation = subset_df_clean1.corr()['SalePrice'].abs().sort_values()
price_correlation
# Out:
# Age              0.520716
# Year Built       0.520716
# Total Bsmt SF    0.635165
# Gr Liv Area      0.740554
# SalePrice        1.000000
# Name: SalePrice, dtype: float64

#
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                 1.366e+04
# Date:                Mon, 15 Apr 2019   Prob (F-statistic):               0.00
# Time:                        15:03:00   Log-Likelihood:                -22909.
# No. Observations:                1928   AIC:                         4.583e+04
# Df Residuals:                    1924   BIC:                         4.585e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Age            -602.0470     23.985    -25.101      0.000    -649.086    -555.008
# Gr Liv Area      85.0412      1.670     50.912      0.000      81.765      88.317
# Total Bsmt SF    55.7050      2.167     25.705      0.000      51.455      59.955
# Central Air_Y   1.81e+04   2534.291      7.140      0.000    1.31e+04    2.31e+04
# ==============================================================================
# Omnibus:                      438.133   Durbin-Watson:                   2.006
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3039.940
# Skew:                           0.884   Prob(JB):                         0.00
# Kurtosis:                       8.892   Cond. No.                     5.96e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.96e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
from sklearn import preprocessing
from sklearn.preprocessing import scale
cnm['liv1'] = scale(cnm['Gr Liv Area'])
cnm['age1'] = scale(cnm['Age'])
cnm['bsmt1'] = scale(cnm['Total Bsmt SF'])
cnm['saleprice1'] = scale(cnm['SalePrice'])
cnm['air1'] = scale(cnm['Central Air_Y'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype uint8 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)

# %%
y = cnm['saleprice1']
x = cnm[['age1','liv1','bsmt1','air1']]
model13 = sm.OLS(y, x)
results13 = model13.fit()
print(results13.summary())
#
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             saleprice1   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.759
# Method:                 Least Squares   F-statistic:                     1522.
# Date:                Mon, 15 Apr 2019   Prob (F-statistic):               0.00
# Time:                        15:03:02   Log-Likelihood:                -1360.7
# No. Observations:                1928   AIC:                             2729.
# Df Residuals:                    1924   BIC:                             2752.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age1          -0.2799      0.013    -22.045      0.000      -0.305      -0.255
# liv1           0.5586      0.012     45.797      0.000       0.535       0.582
# bsmt1          0.3037      0.013     23.550      0.000       0.278       0.329
# air1           0.0291      0.012      2.417      0.016       0.005       0.053
# ==============================================================================
# Omnibus:                      519.969   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3816.568
# Skew:                           1.065   Prob(JB):                         0.00
# Kurtosis:                       9.555   Cond. No.                         1.85
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# do log
cnm['sale log'] = np.log(cnm['SalePrice'] + 1)
import seaborn as sns
y_train = cnm['SalePrice']
y_train_log = cnm['sale log']
f, axes = plt.subplots(1, 2, figsize = (15, 5))            
sns.kdeplot(y_train, ax = axes[0], legend = None)
axes[0].set_title('SalePrice')
sns.kdeplot(y_train_log, ax = axes[1], legend = None，shade=True)
axes[1].set_title('log(SalePrice)')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-f2f3acaef868> in <module>
#       7 sns.kdeplot(y_train, ax = axes[0], legend = None)
#       8 axes[0].set_title('SalePrice')
# ----> 9 sns.kdeplot(y_train_log, ax = axes[1], legend = None,ay=axes[1])
#      10 axes[1].set_title('log(SalePrice)')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py in kdeplot(data, data2, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#     689         ax = _univariate_kdeplot(data, shade, vertical, kernel, bw,
#     690                                  gridsize, cut, clip, legend, ax,
# --> 691                                  cumulative=cumulative, **kwargs)
#     692
#     693     return ax
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py in _univariate_kdeplot(data, shade, vertical, kernel, bw, gridsize, cut, clip, legend, ax, cumulative, **kwargs)
#     314     # Use the active color cycle to find the plot color
#     315     facecolor = kwargs.pop("facecolor", None)
# --> 316     line, = ax.plot(x, y, **kwargs)
#     317     color = line.get_color()
#     318     line.remove()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     381                                   "with non-matching shapes is deprecated.")
#     382         for j in range(max(ncx, ncy)):
# --> 383             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     384             ret.append(seg)
#     385         return ret
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_base.py in _makeline(self, x, y, kw, kwargs)
#     286         default_dict = self._getdefaults(None, kw)
#     287         self._setdefaults(default_dict, kw)
# --> 288         seg = mlines.Line2D(x, y, **kw)
#     289         return seg
#     290
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     408         # update kwargs before updating data to give the caller a
#     409         # chance to init axes (and hence unit support)
# --> 410         self.update(kwargs)
#     411         self.pickradius = pickradius
#     412         self.ind_offset = 0
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     910                 func = getattr(self, 'set_' + k, None)
#     911                 if not callable(func):
# --> 912                     raise AttributeError('Unknown property %s' % k)
#     913                 return func(v)
#     914
#
# AttributeError: Unknown property ay
